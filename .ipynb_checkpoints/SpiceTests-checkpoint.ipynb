# %%
#Required imports
import spice
import pvlparser
from osgeo import gdal

#Testing
import pprint

# %%
dir(spice)
# Out:
# ['Cell',
#  'DataType',
#  'EkAttDsc',
#  'EkSegSum',
#  'Ellipse',
#  'Plane',
#  'SpiceException',
#  '__builtins__',
#  '__doc__',
#  '__file__',
#  '__name__',
#  '__package__',
#  '__path__',
#  'axisar',
#  'b1900',
#  'b1950',
#  'badkpv',
#  'bodc2n',
#  'bodc2s',
#  'boddef',
#  'bodfnd',
#  'bodn2c',
#  'bods2c',
#  'bodvcd',
#  'bodvrd',
#  'brcktd',
#  'brckti',
#  'bschoi',
#  'bsrchd',
#  'bsrchi',
#  'card',
#  'cgv2el',
#  'chkin',
#  'chkout',
#  'cidfrm',
#  'ckcls',
#  'ckcov',
#  'ckgp',
#  'ckgpav',
#  'cklpf',
#  'ckobj',
#  'ckopn',
#  'ckupf',
#  'clight',
#  'clpool',
#  'cmprss',
#  'cnmfrm',
#  'conics',
#  'convrt',
#  'copy',
#  'cpos',
#  'cposr',
#  'cvpool',
#  'cyllat',
#  'cylrec',
#  'cylsph',
#  'dafbbs',
#  'dafbfs',
#  'dafcls',
#  'dafcs',
#  'dafdc',
#  'daffna',
#  'daffpa',
#  'dafgda',
#  'dafgn',
#  'dafgsr',
#  'dafopr',
#  'dafopw',
#  'dafrda',
#  'dafrfr',
#  'dafrs',
#  'dascls',
#  'dasopr',
#  'dcyldr',
#  'deltet',
#  'det',
# ...

# %%
#Reproduce the ISIS3 Test
testdata = '/Volumes/Scrath/ISIS3/mro_kernels/mro/testData/frt0001cfd8_07_if124s_trr3_b24.cub'

# %%
ds = gdal.Open(testdata)
ds
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x1035c37e0> >

# %%
header = pvlparser.getheader(testdata)

# %% [markdown]
# From the spiceinit documentation
#
# The program uses the "SpacecraftName", "InstrumentId", "TargetName", "StartTime", and "StopTime" keywords from the cube's label to determine which kernels to use. It attempts to find kernel files for the following keywords and writes them to the Kernels group:

# %%
spacecraftname = header['IsisCube']['Instrument']['SpacecraftName']
instrumentid = header['IsisCube']['Instrument']['InstrumentId']
targetname = header['IsisCube']['Instrument']['TargetName']
starttime = header['IsisCube']['Instrument']['StartTime']
stoptime = header['IsisCube']['Instrument']['StopTime']
